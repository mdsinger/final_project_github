# %%
# Initial imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load the data.csv dataset.
file_path = "Population-by-County-1850-2010.csv"
df = pd.read_csv(file_path)#, index_col=0)
df
# Out:
#                County   1850    1860    1870    1880    1890    1900     1910  \
# 0       Beaver County     na     785   2,007   3,918   3,340   3,613    4,717
# 1    Box Elder County     na   1,608   4,855   6,761   7,642  10,009   13,894
# 2        Cache County     na   2,605   8,229  12,562  15,509  18,139   23,062
# 3       Carbon County     na      na      na      na      na   5,004    8,624
# 4      Daggett County     na      na      na      na      na      na       na
# 5        Davis County  1,134   2,904   4,459   5,279   6,751   7,996   10,191
# 6        Duche County     na      na      na      na      na      na       na
# 7        Emery County     na      na      na     556   5,076   4,657    6,750
# 8     Garfield County     na      na      na      na   2,457   3,400    3,660
# 9        Grand County     na      na      na      na     541   1,149    1,595
# 10        Iron County    360   1,010   2,277   4,013   2,683   3,546    3,933
# 11        Juab County     na     672   2,034   3,474   5,582  10,082   10,702
# 12        Kane County     na      na   1,513   3,085   1,685   1,811    1,652
# 13     Millard County     na     715   2,753   3,727   4,033   5,678    6,118
# 14      Morgan County     na      na   1,972   1,783   1,780   2,045    2,467
# 15       Piute County     na      na      82   1,651   2,842   1,954    1,734
# 16        Rich County     na      na   1,955   1,263   1,527   1,946    1,883
# 17   Salt Lake County  6,157  11,295  18,337  31,977  58,457  77,725  131,426
# 18    San Juan County     na      na      na     204     365   1,023    2,377
# 19     Sanpete County    365   3,815   6,786  11,557  13,146  16,313   16,704
# 20      Sevier County     na      na      na   4,457   6,199   8,451    9,775
# 21      Summit County     na     198   2,512   4,921   7,733   9,439    8,200
# 22      Tooele County    152   1,008   2,177   4,497   3,700   7,361    7,924
# 23      Uintah County     na      na      na     799   2,762   6,458    7,050
# 24        Utah County  2,026   8,248  12,203  17,973  23,768  32,456   37,942
# 25     Wasatch County     na      na   1,244   2,927   3,595   4,736    8,920
# 26  Washington County     na     691   3,064   4,235   4,009   4,612    5,123
# 27       Wayne County     na      na      na      na      na   1,907    1,749
# 28       Weber County  1,186   3,675   7,858  12,344  22,723  25,239   35,179
#
#        1920     1930     1940     1950     1960     1970     1980     1990  \
# 0     5,139    5,136    5,014    4,856    4,331    3,800    4,378    4,765
# 1    18,788   17,810   18,832   19,734   25,061   28,129   33,222   36,485
# 2    26,992   27,424   29,797   33,536   35,788   42,331   57,176   70,183
# 3    15,489   17,798   18,459   24,901   21,135   15,647   22,179   20,228
# 4       400      411      564      364    1,164      666      769      690
# 5    11,450   14,021   15,784   30,867   64,760   99,028  146,540  187,941
# 6     9,093    8,263    8,958    8,134    7,179    7,299   12,565   12,645
# 7     7,411    7,042    7,072    6,304    5,546    5,137   11,451   10,332
# 8     4,768    4,642    5,253    4,151    3,577    3,157    3,673    3,980
# 9     1,808    1,813    2,070    1,903    6,345    6,688    8,241    6,620
# 10    5,787    7,227    8,331    9,642   10,795   12,177   17,349   20,789
# 11    9,871    8,605    7,392    5,981    4,597    4,574    5,530    5,817
# 12    2,054    2,235    2,561    2,299    2,667    2,421    4,024    5,169
# 13    9,659    9,945    9,613    9,387    7,866    6,988    8,970   11,333
# 14    2,542    2,536    2,611    2,519    2,837    3,983    4,917    5,528
# 15    2,770    1,956    2,203    1,911    1,436    1,164    1,329    1,277
# 16    1,890    1,873    2,028    1,673    1,685    1,615    2,100    1,725
# 17  159,282  194,102  211,623  274,895  383,035  458,607  619,066  725,956
# 18    3,379    3,496    4,712    5,315    9,040    9,606   12,253   12,621
# 19   17,505   16,022   16,063   13,891   11,053   10,976   14,620   16,259
# 20   11,281   11,199   12,112   12,072   10,565   10,103   14,727   15,431
# 21    7,862    9,527    8,714    6,745    5,673    5,879   10,198   15,518
# 22    7,965    9,413    9,133   14,636   17,868   21,545   26,033   26,601
# 23    8,470    9,035    9,898   10,300   11,582   12,684   20,506   22,211
# 24   40,792   49,021   57,382   81,912  106,991  137,776  218,106  263,590
# 25    4,625    5,636    5,754    5,574    5,308    5,863    8,523   10,089
# 26    6,764    7,420    9,269    9,836   10,271   13,669   26,065   48,560
# 27    2,097    2,067    2,394    2,205    1,728    1,483    1,911    2,177
# 28   43,463   52,172   56,714   83,319  110,744  126,278  144,616  158,330
#
#        2000       2010
# 0     6,005      6,629
# 1    42,745     49,975
# 2    91,391    112,656
# 3    20,422     21,403
# 4       921      1,059
# 5   238,994    306,479
# 6    14,371     18,607
# 7    10,860     10,976
# 8     4,735      5,172
# 9     8,485      9,225
# 10   33,779     46,163
# 11    8,238     10,246
# 12    6,046      7,125
# 13   12,405     12,503
# 14    7,129      9,469
# 15    1,435      1,556
# 16    1,961      2,264
# 17  898,387  1,029,655
# 18   14,413     14,746
# 19   22,763     27,822
# 20   18,842     20,802
# 21   29,736     36,324
# 22   40,735     58,218
# 23   25,224     32,588
# 24  368,536    516,564
# 25   15,215     23,530
# 26   90,354    138,115
# 27    2,509      2,778
# 28  196,533    231,236

# %%
df.columns
# Out:
# Index(['County', '1850', '1860', '1870', '1880', '1890', '1900', '1910',
#        '1920', '1930', '1940', '1950', '1960', '1970', '1980', '1990', '2000',
#        '2010'],
#       dtype='object')

# %%
#Remove columns
df=df.drop(["1850", "1860", "1870","1880","1890", "1900", "1910", "1920","1930","1940", "1950", "1960","1970"], axis=1)
df
# Out:
#                County     1980     1990     2000       2010
# 0       Beaver County    4,378    4,765    6,005      6,629
# 1    Box Elder County   33,222   36,485   42,745     49,975
# 2        Cache County   57,176   70,183   91,391    112,656
# 3       Carbon County   22,179   20,228   20,422     21,403
# 4      Daggett County      769      690      921      1,059
# 5        Davis County  146,540  187,941  238,994    306,479
# 6        Duche County   12,565   12,645   14,371     18,607
# 7        Emery County   11,451   10,332   10,860     10,976
# 8     Garfield County    3,673    3,980    4,735      5,172
# 9        Grand County    8,241    6,620    8,485      9,225
# 10        Iron County   17,349   20,789   33,779     46,163
# 11        Juab County    5,530    5,817    8,238     10,246
# 12        Kane County    4,024    5,169    6,046      7,125
# 13     Millard County    8,970   11,333   12,405     12,503
# 14      Morgan County    4,917    5,528    7,129      9,469
# 15       Piute County    1,329    1,277    1,435      1,556
# 16        Rich County    2,100    1,725    1,961      2,264
# 17   Salt Lake County  619,066  725,956  898,387  1,029,655
# 18    San Juan County   12,253   12,621   14,413     14,746
# 19     Sanpete County   14,620   16,259   22,763     27,822
# 20      Sevier County   14,727   15,431   18,842     20,802
# 21      Summit County   10,198   15,518   29,736     36,324
# 22      Tooele County   26,033   26,601   40,735     58,218
# 23      Uintah County   20,506   22,211   25,224     32,588
# 24        Utah County  218,106  263,590  368,536    516,564
# 25     Wasatch County    8,523   10,089   15,215     23,530
# 26  Washington County   26,065   48,560   90,354    138,115
# 27       Wayne County    1,911    2,177    2,509      2,778
# 28       Weber County  144,616  158,330  196,533    231,236

# %%
df.dtypes
# Out:
# County    object
# 1980      object
# 1990      object
# 2000      object
# 2010      object
# dtype: object

# %%
#Rename columns
df.rename(columns={"1980":"1980 Census","1990":"1990 Census", "2000":"2000 Census", "2010":"2010 Census"}, inplace=True)
df.head()
# Out:
#              County 1980 Census 1990 Census 2000 Census 2010 Census
# 0     Beaver County       4,378       4,765       6,005       6,629
# 1  Box Elder County      33,222      36,485      42,745      49,975
# 2      Cache County      57,176      70,183      91,391     112,656
# 3     Carbon County      22,179      20,228      20,422      21,403
# 4    Daggett County         769         690         921       1,059

# %%
len(df)
# Out:
# 29

# %%
#Save new df
df.to_csv("data1.csv")

# %%
# Load the data.csv dataset.
file_path = "2010 2020 Census.csv"
latest_df = pd.read_csv(file_path)#, index_col=0)
latest_df
# Out:
#                County             Variable       Series 2010 Census  \
# 0       Beaver County  Population Estimate  Intercensal       6,629
# 1    Box Elder County  Population Estimate  Intercensal      49,975
# 2        Cache County  Population Estimate  Intercensal     112,656
# 3       Carbon County  Population Estimate  Intercensal      21,403
# 4      Daggett County  Population Estimate  Intercensal       1,059
# 5        Davis County  Population Estimate  Intercensal     306,479
# 6     Duchesne County  Population Estimate  Intercensal      18,607
# 7        Emery County  Population Estimate  Intercensal      10,976
# 8     Garfield County  Population Estimate  Intercensal       5,172
# 9        Grand County  Population Estimate  Intercensal       9,225
# 10        Iron County  Population Estimate  Intercensal      46,163
# 11        Juab County  Population Estimate  Intercensal      10,246
# 12        Kane County  Population Estimate  Intercensal       7,125
# 13     Millard County  Population Estimate  Intercensal      12,503
# 14      Morgan County  Population Estimate  Intercensal       9,469
# 15       Piute County  Population Estimate  Intercensal       1,556
# 16        Rich County  Population Estimate  Intercensal       2,264
# 17   Salt Lake County  Population Estimate  Intercensal   1,029,655
# 18    San Juan County  Population Estimate  Intercensal      14,746
# 19     Sanpete County  Population Estimate  Intercensal      27,822
# 20      Sevier County  Population Estimate  Intercensal      20,802
# 21      Summit County  Population Estimate  Intercensal      36,324
# 22      Tooele County  Population Estimate  Intercensal      58,218
# 23      Uintah County  Population Estimate  Intercensal      32,588
# 24        Utah County  Population Estimate  Intercensal     516,564
# 25     Wasatch County  Population Estimate  Intercensal      23,530
# 26  Washington County  Population Estimate  Intercensal     138,115
# 27       Wayne County  Population Estimate  Intercensal       2,778
# 28       Weber County  Population Estimate  Intercensal     231,236
#
#          2010       2011       2012       2013       2014       2015  \
# 0       6,645      6,668      6,689      6,782      6,697      6,755
# 1      50,084     50,725     51,308     52,016     52,571     53,327
# 2     113,307    115,004    116,405    117,600    118,876    121,874
# 3      21,390     21,358     21,324     20,958     20,702     20,549
# 4       1,076      1,099      1,096      1,131      1,079      1,071
# 5     307,712    313,717    319,263    325,546    331,327    337,940
# 6      18,689     18,859     19,407     19,865     20,031     20,147
# 7      10,991     11,023     10,775     10,673     10,488     10,221
# 8       5,167      5,185      5,193      5,173      5,133      5,088
# 9       9,227      9,340      9,431      9,412      9,446      9,536
# 10     46,241     47,052     47,486     47,875     48,525     49,821
# 11     10,260     10,279     10,304     10,343     10,482     10,650
# 12      7,113      7,184      7,274      7,281      7,215      7,207
# 13     12,513     12,597     12,619     12,672     12,651     12,646
# 14      9,516      9,705     10,033     10,396     10,747     11,045
# 15      1,548      1,540      1,521      1,510      1,473      1,482
# 16      2,280      2,303      2,297      2,330      2,363      2,403
# 17  1,032,281  1,049,380  1,065,591  1,078,405  1,090,830  1,106,942
# 18     14,715     14,759     14,947     14,854     14,835     14,749
# 19     27,834     27,984     27,825     27,678     27,458     27,548
# 20     20,793     20,788     20,863     20,746     20,743     20,798
# 21     36,573     37,449     38,032     38,350     38,858     39,502
# 22     58,369     59,208     60,233     61,516     62,378     63,506
# 23     32,722     33,752     34,703     35,649     36,331     36,595
# 24    518,707    531,930    543,411    552,265    564,419    582,261
# 25     23,689     24,671     25,877     26,874     27,976     29,397
# 26    138,435    141,076    142,763    145,187    148,057    151,588
# 27      2,775      2,731      2,710      2,657      2,621      2,579
# 28    232,014    234,726    238,024    240,280    242,673    246,564
#
#          2016       2017       2018       2019 2020 Census
# 0       6,835      6,906      6,981      7,055       7,072
# 1      54,464     55,463     56,245     56,956      57,666
# 2     123,927    126,491    128,888    131,388     133,154
# 3      20,456     20,355     20,423     20,391      20,412
# 4       1,053        915        915        918         935
# 5     344,842    351,297    355,688    360,196     362,679
# 6      19,805     19,896     19,790     19,657      19,596
# 7      10,052     10,064      9,977      9,890       9,825
# 8       5,100      5,134      5,109      5,092       5,083
# 9       9,671      9,743      9,903      9,715       9,669
# 10     51,235     52,844     54,795     56,122      57,289
# 11     11,039     11,215     11,514     11,711      11,786
# 12      7,505      7,467      7,615      7,600       7,667
# 13     12,745     12,844     12,865     12,934      12,975
# 14     11,479     11,675     11,906     12,125      12,295
# 15      1,426      1,401      1,428      1,449       1,438
# 16      2,415      2,437      2,504      2,483       2,510
# 17  1,123,506  1,145,202  1,161,347  1,174,562   1,185,238
# 18     14,931     14,717     14,651     14,617      14,518
# 19     27,656     27,905     28,157     28,288      28,437
# 20     20,992     21,154     21,232     21,438      21,522
# 21     40,316     41,078     41,634     42,215      42,357
# 22     65,575     67,465     69,235     71,312      72,698
# 23     35,627     35,503     35,660     35,558      35,620
# 24    599,268    612,960    628,149    645,315     659,399
# 25     30,928     32,303     33,365     34,242      34,788
# 26    156,766    161,411    166,285    175,215     180,279
# 27      2,545      2,536      2,522      2,496       2,486
# 28    250,224    254,097    257,559    260,168     262,223

# %%
latest_df.columns
# Out:
# Index(['County', 'Variable', 'Series', '2010 Census', '2010', '2011', '2012',
#        '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020 Census'],
#       dtype='object')

# %%
#Create new Df
latest_df=latest_df[["County","2020 Census"]]
latest_df.head()
# Out:
#              County 2020 Census
# 0     Beaver County       7,072
# 1  Box Elder County      57,666
# 2      Cache County     133,154
# 3     Carbon County      20,412
# 4    Daggett County         935

# %%
len(latest_df)
# Out:
# 29

# %%
#Save new df
latest_df.to_csv("data2.csv")

# %%
# Load the data.csv dataset.
file_path = "Predictions 2022.csv"
predictions_df = pd.read_csv(file_path)#, index_col=0)
predictions_df.head()
# Out:
#              County Unnamed: 1     2020     2021     2022
# 0     Beaver County      7,074    7,087    7,203    7,327
# 1  Box Elder County     57,669   57,946   59,693   61,498
# 2      Cache County    133,159  133,624  137,429  140,173
# 3     Carbon County     20,418   20,488   20,361   20,571
# 4    Daggett County        936      952      977    1,014

# %%
#Create new Df
predictions_df=predictions_df[["County","2022"]]
predictions_df
# Out:
#                County       2022
# 0       Beaver County      7,327
# 1    Box Elder County     61,498
# 2        Cache County    140,173
# 3       Carbon County     20,571
# 4      Daggett County      1,014
# 5        Davis County    369,948
# 6     Duchesne County     20,161
# 7        Emery County     10,099
# 8     Garfield County      5,281
# 9        Grand County      9,769
# 10        Iron County     62,429
# 11        Juab County     12,567
# 12        Kane County      8,227
# 13     Millard County     13,330
# 14      Morgan County     12,832
# 15       Piute County      1,487
# 16        Rich County      2,628
# 17   Salt Lake County  1,186,257
# 18    San Juan County     14,359
# 19     Sanpete County     29,724
# 20      Sevier County     22,069
# 21      Summit County     43,036
# 22      Tooele County     79,934
# 23      Uintah County     37,141
# 24        Utah County    702,434
# 25     Wasatch County     36,619
# 26  Washington County    197,680
# 27       Wayne County      2,645
# 28       Weber County    269,561

# %%
len(predictions_df)
# Out:
# 29

# %%
#Rename columns
predictions_df.rename(columns={"2022":"2022 Predictions"}, inplace=True)
predictions_df.head()
# Out:
#              County 2022 Predictions
# 0     Beaver County            7,327
# 1  Box Elder County           61,498
# 2      Cache County          140,173
# 3     Carbon County           20,571
# 4    Daggett County            1,014

# %%
#save file
predictions_df.to_csv("data3.csv")

# %%
#Merge the dataframes on the 'key' column
population_df = pd.merge(df, latest_df, on='County', how='outer')
population_df = pd.merge(population_df, predictions_df, on='County', how='outer')

# print the merged dataframe
population_df
# Out:
#                County 1980 Census 1990 Census 2000 Census 2010 Census  \
# 0       Beaver County       4,378       4,765       6,005       6,629
# 1    Box Elder County      33,222      36,485      42,745      49,975
# 2        Cache County      57,176      70,183      91,391     112,656
# 3       Carbon County      22,179      20,228      20,422      21,403
# 4      Daggett County         769         690         921       1,059
# 5        Davis County     146,540     187,941     238,994     306,479
# 6        Duche County      12,565      12,645      14,371      18,607
# 7        Emery County      11,451      10,332      10,860      10,976
# 8     Garfield County       3,673       3,980       4,735       5,172
# 9        Grand County       8,241       6,620       8,485       9,225
# 10        Iron County      17,349      20,789      33,779      46,163
# 11        Juab County       5,530       5,817       8,238      10,246
# 12        Kane County       4,024       5,169       6,046       7,125
# 13     Millard County       8,970      11,333      12,405      12,503
# 14      Morgan County       4,917       5,528       7,129       9,469
# 15       Piute County       1,329       1,277       1,435       1,556
# 16        Rich County       2,100       1,725       1,961       2,264
# 17   Salt Lake County     619,066     725,956     898,387   1,029,655
# 18    San Juan County      12,253      12,621      14,413      14,746
# 19     Sanpete County      14,620      16,259      22,763      27,822
# 20      Sevier County      14,727      15,431      18,842      20,802
# 21      Summit County      10,198      15,518      29,736      36,324
# 22      Tooele County      26,033      26,601      40,735      58,218
# 23      Uintah County      20,506      22,211      25,224      32,588
# 24        Utah County     218,106     263,590     368,536     516,564
# 25     Wasatch County       8,523      10,089      15,215      23,530
# 26  Washington County      26,065      48,560      90,354     138,115
# 27       Wayne County       1,911       2,177       2,509       2,778
# 28       Weber County     144,616     158,330     196,533     231,236
# 29    Duchesne County         NaN         NaN         NaN         NaN
#
#    2020 Census 2022 Predictions
# 0        7,072            7,327
# 1       57,666           61,498
# 2      133,154          140,173
# 3       20,412           20,571
# 4          935            1,014
# 5      362,679          369,948
# 6          NaN              NaN
# 7        9,825           10,099
# 8        5,083            5,281
# 9        9,669            9,769
# 10      57,289           62,429
# 11      11,786           12,567
# 12       7,667            8,227
# 13      12,975           13,330
# 14      12,295           12,832
# 15       1,438            1,487
# 16       2,510            2,628
# 17   1,185,238        1,186,257
# 18      14,518           14,359
# 19      28,437           29,724
# 20      21,522           22,069
# 21      42,357           43,036
# 22      72,698           79,934
# 23      35,620           37,141
# 24     659,399          702,434
# 25      34,788           36,619
# 26     180,279          197,680
# 27       2,486            2,645
# 28     262,223          269,561
# 29      19,596           20,161

# %%
population_df.to_csv("population.csv")

# %%
population_df.dtypes
# Out:
# County              object
# 1980 Census         object
# 1990 Census         object
# 2000 Census         object
# 2010 Census         object
# 2020 Census         object
# 2022 Predictions    object
# dtype: object

# %%
population_df=population_df.replace(',',"",regex=True)
population_df=population_df.astype({"1980 Census":float,"1990 Census":float,"2020 Census":float, "2000 Census":float, "2010 Census":float, "2020 Census":float, "2022 Predictions":float })
population_df.dtypes
# Out:
# County               object
# 1980 Census         float64
# 1990 Census         float64
# 2000 Census         float64
# 2010 Census         float64
# 2020 Census         float64
# 2022 Predictions    float64
# dtype: object

# %%
population_df
# Out:
#                County  1980 Census  1990 Census  2000 Census  2010 Census  \
# 0       Beaver County       4378.0       4765.0       6005.0       6629.0
# 1    Box Elder County      33222.0      36485.0      42745.0      49975.0
# 2        Cache County      57176.0      70183.0      91391.0     112656.0
# 3       Carbon County      22179.0      20228.0      20422.0      21403.0
# 4      Daggett County        769.0        690.0        921.0       1059.0
# 5        Davis County     146540.0     187941.0     238994.0     306479.0
# 6        Duche County      12565.0      12645.0      14371.0      18607.0
# 7        Emery County      11451.0      10332.0      10860.0      10976.0
# 8     Garfield County       3673.0       3980.0       4735.0       5172.0
# 9        Grand County       8241.0       6620.0       8485.0       9225.0
# 10        Iron County      17349.0      20789.0      33779.0      46163.0
# 11        Juab County       5530.0       5817.0       8238.0      10246.0
# 12        Kane County       4024.0       5169.0       6046.0       7125.0
# 13     Millard County       8970.0      11333.0      12405.0      12503.0
# 14      Morgan County       4917.0       5528.0       7129.0       9469.0
# 15       Piute County       1329.0       1277.0       1435.0       1556.0
# 16        Rich County       2100.0       1725.0       1961.0       2264.0
# 17   Salt Lake County     619066.0     725956.0     898387.0    1029655.0
# 18    San Juan County      12253.0      12621.0      14413.0      14746.0
# 19     Sanpete County      14620.0      16259.0      22763.0      27822.0
# 20      Sevier County      14727.0      15431.0      18842.0      20802.0
# 21      Summit County      10198.0      15518.0      29736.0      36324.0
# 22      Tooele County      26033.0      26601.0      40735.0      58218.0
# 23      Uintah County      20506.0      22211.0      25224.0      32588.0
# 24        Utah County     218106.0     263590.0     368536.0     516564.0
# 25     Wasatch County       8523.0      10089.0      15215.0      23530.0
# 26  Washington County      26065.0      48560.0      90354.0     138115.0
# 27       Wayne County       1911.0       2177.0       2509.0       2778.0
# 28       Weber County     144616.0     158330.0     196533.0     231236.0
# 29    Duchesne County          NaN          NaN          NaN          NaN
#
#     2020 Census  2022 Predictions
# 0        7072.0            7327.0
# 1       57666.0           61498.0
# 2      133154.0          140173.0
# 3       20412.0           20571.0
# 4         935.0            1014.0
# 5      362679.0          369948.0
# 6           NaN               NaN
# 7        9825.0           10099.0
# 8        5083.0            5281.0
# 9        9669.0            9769.0
# 10      57289.0           62429.0
# 11      11786.0           12567.0
# 12       7667.0            8227.0
# 13      12975.0           13330.0
# 14      12295.0           12832.0
# 15       1438.0            1487.0
# 16       2510.0            2628.0
# 17    1185238.0         1186257.0
# 18      14518.0           14359.0
# 19      28437.0           29724.0
# 20      21522.0           22069.0
# 21      42357.0           43036.0
# 22      72698.0           79934.0
# 23      35620.0           37141.0
# 24     659399.0          702434.0
# 25      34788.0           36619.0
# 26     180279.0          197680.0
# 27       2486.0            2645.0
# 28     262223.0          269561.0
# 29      19596.0           20161.0

# %%
fp_df=population_df.iloc[[5,17,24]]
fp_df
# Out:
#               County  1980 Census  1990 Census  2000 Census  2010 Census  \
# 5       Davis County     146540.0     187941.0     238994.0     306479.0
# 17  Salt Lake County     619066.0     725956.0     898387.0    1029655.0
# 24       Utah County     218106.0     263590.0     368536.0     516564.0
#
#     2020 Census  2022 Predictions
# 5      362679.0          369948.0
# 17    1185238.0         1186257.0
# 24     659399.0          702434.0

# %%
fp_df.columns
# Out:
# Index(['County', '1980 Census', '1990 Census', '2000 Census', '2010 Census',
#        '2020 Census', '2022 Predictions'],
#       dtype='object')

# %%
fp_df.dtypes
# Out:
# County               object
# 1980 Census         float64
# 1990 Census         float64
# 2000 Census         float64
# 2010 Census         float64
# 2020 Census         float64
# 2022 Predictions    float64
# dtype: object

# %%
fp_df.to_csv("fp.csv")

# %%
new_df=pd.read_csv("fp.csv")

# %%
davis_df=population_df.iloc[[5]]
davis_df
# Out:
#          County  1980 Census  1990 Census  2000 Census  2010 Census  \
# 5  Davis County     146540.0     187941.0     238994.0     306479.0
#
#    2020 Census  2022 Predictions
# 5     362679.0          369948.0

# %%
davis_df.to_csv("davis.csv")

# %%
#Plot Bar Chart
ax = fp_df.plot(x='County', y=['1980 Census', '1990 Census', '2000 Census', '2010 Census', '2020 Census', '2022 Predictions'],
             kind='bar', figsize=(10, 6))
ax.set_xlabel('County')
ax.set_ylabel('Population')
ax.set_title('Population Census Data')

# Add labels for each individual bar
for container in ax.containers:
    ax.bar_label(container)

plt.show()

# %%
import seaborn as sns

# Create a dataframe 
data = {'County': ['Davis County', 'Salt Lake County', 'Utah County'],
        '1980 Census': [146540, 619066, 218106],
        '1990 Census': [187941, 725956, 263590],
        '2000 Census': [238994, 898387, 368536],
        '2010 Census': [306479, 1029655, 516564],
        '2020 Census': [362679, 1185238, 659399],
        '2022 Predictions': [369948, 1186257, ]}
df = pd.DataFrame(data)

# Set 'County' as the index
df.set_index('County', inplace=True)


plt.figure(figsize=(10, 6))  # Adjust the width and height as needed

# Plot the heatmap
sns.heatmap(df, cmap='YlGnBu', annot=True, fmt=",d", cbar=True)
plt.title('Population by County and Year Heatmap')
plt.xlabel('Year')
plt.ylabel('County')
plt.show()
